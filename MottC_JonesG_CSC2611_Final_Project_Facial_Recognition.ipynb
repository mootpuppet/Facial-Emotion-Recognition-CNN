# %% [markdown]
# # Emotion Recognition Model
# #### Gavin Jones, Cody Mott
#
# ###### Description

# %% [markdown]
# ##### Import libraries

# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow.keras as keras
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sns
# Out:
# 2023-12-06 13:59:27.382566: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-06 13:59:27.426121: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ##### Import data

# %%
# import data

face_data_df = pd.read_csv("data/icml_face_data.csv")
face_data_df.head()

print(face_data_df.columns)
# Out:
# Index(['emotion', ' Usage', ' pixels'], dtype='object')

# %% [markdown]
# # Preprocess Data

# %%
# drop unnesccary columns

face_data_df.drop(' Usage', axis=1, inplace= True)
print(face_data_df.columns)
# Out:
# Index(['emotion', ' pixels'], dtype='object')

# %%
# convert string format images into array format

face_data_df[' pixels'] = face_data_df[' pixels'].apply(
    lambda x: np.array(x.split(' ')).reshape(48, 48, 1).astype('float32'))

# %%
# split into images and labels
images = face_data_df[' pixels'].to_numpy()
labels = face_data_df['emotion'].to_numpy()

# normalize images
images = np.stack(images, axis=0)/255

# one hot encode labels
labels = tf.keras.utils.to_categorical(labels, num_classes=7)

# split data into train/validation/testing 70%/20%/10%

# 70% training, 30% temp
image_train, image_temp, label_train, label_temp = train_test_split(images, labels, test_size=0.3)  

# 67% training, 33% temp
image_val, image_test, label_val, label_test = train_test_split(image_temp, label_temp, test_size=0.33)  


#emotion dictionary
emotions = {0: "angry", 1: "disgust", 2: "fear", 3: "happy", 4: "sad", 5: "surprise", 6: "neutral"}

# %%
def count_data(labels):
    # Assuming label_train is a one-hot encoded array
    # Convert it back to integer labels
    

    # Count the number of samples for each category
    unique_labels_train, counts_train = np.unique(np.argmax(labels, axis=1), return_counts=True)

    #
    label_count_list = []

    # Display the count for each category
    for label, count in zip(unique_labels_train, counts_train):
        #print(f"Category {label}: {count} samples in data")
        label_count_list.append(count)

    return label_count_list

# %%
count_data(labels)
# Out:
# [4953, 547, 5121, 8989, 6077, 4002, 6198]

# %%
print(images.shape)
# Out:
# (35887, 48, 48, 1)

# %%
index = random.randint(0,image_train.shape[0]-1)
print(index)
plt.imshow(image_train[index], cmap='gray')
plt.axis('off') 
plt.show()
# Out:
# 7420

# %% [markdown]
# # Base Model

# %% [markdown]
# ##### Build and compile

# %%
model = Sequential()

# Convolutional layer 1
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Convolutional layer 2
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


# Flatten the data for dense layers
model.add(Flatten())

# Dense layers
model.add(Dense(256, activation='relu'))
model.add(Dense(7, activation='softmax'))  # 7 output classes for emotions

# Optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.001)

# Compile the model
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# 2023-12-06 13:59:58.498807: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1638] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13797 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:da:00.0, compute capability: 7.5

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 256)               1638656
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 1,659,271
# Trainable params: 1,659,271
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### Training

# %%
hist = model.fit(image_train, label_train, epochs=20, 
                    validation_data=(image_val, label_val), batch_size=32)
# Out:
# Epoch 1/20
# 2023-12-06 13:59:59.705096: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8901
# 2023-12-06 13:59:59.950533: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7fb5c4991a80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-06 13:59:59.950571: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2023-12-06 13:59:59.954773: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-06 14:00:00.081461: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 785/785 [==============================] - 6s 6ms/step - loss: 1.5956 - accuracy: 0.3699 - val_loss: 1.4533 - val_accuracy: 0.4556
# Epoch 2/20
# 785/785 [==============================] - 4s 5ms/step - loss: 1.3785 - accuracy: 0.4709 - val_loss: 1.3816 - val_accuracy: 0.4805
# Epoch 3/20
# 785/785 [==============================] - 4s 5ms/step - loss: 1.2561 - accuracy: 0.5182 - val_loss: 1.3350 - val_accuracy: 0.4990
# Epoch 4/20
# 785/785 [==============================] - 4s 5ms/step - loss: 1.1411 - accuracy: 0.5695 - val_loss: 1.2946 - val_accuracy: 0.5120
# Epoch 5/20
# 785/785 [==============================] - 4s 5ms/step - loss: 1.0150 - accuracy: 0.6182 - val_loss: 1.3816 - val_accuracy: 0.5048
# Epoch 6/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.8739 - accuracy: 0.6791 - val_loss: 1.4053 - val_accuracy: 0.5241
# Epoch 7/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.7186 - accuracy: 0.7409 - val_loss: 1.4888 - val_accuracy: 0.5213
# Epoch 8/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.5587 - accuracy: 0.8055 - val_loss: 1.6054 - val_accuracy: 0.5292
# Epoch 9/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.4106 - accuracy: 0.8609 - val_loss: 1.8908 - val_accuracy: 0.5159
# Epoch 10/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.2920 - accuracy: 0.9055 - val_loss: 2.1601 - val_accuracy: 0.5228
# Epoch 11/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.2018 - accuracy: 0.9379 - val_loss: 2.5101 - val_accuracy: 0.5145
# Epoch 12/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.1482 - accuracy: 0.9563 - val_loss: 2.8071 - val_accuracy: 0.5095
# Epoch 13/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.1221 - accuracy: 0.9652 - val_loss: 2.9415 - val_accuracy: 0.5113
# Epoch 14/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.1023 - accuracy: 0.9712 - val_loss: 3.1619 - val_accuracy: 0.5202
# Epoch 15/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.0885 - accuracy: 0.9762 - val_loss: 3.3854 - val_accuracy: 0.5213
# Epoch 16/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.0884 - accuracy: 0.9758 - val_loss: 3.4781 - val_accuracy: 0.5139
# Epoch 17/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.0824 - accuracy: 0.9787 - val_loss: 3.6728 - val_accuracy: 0.5232
# Epoch 18/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.0772 - accuracy: 0.9802 - val_loss: 3.7218 - val_accuracy: 0.5067
# Epoch 19/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.0759 - accuracy: 0.9786 - val_loss: 3.7526 - val_accuracy: 0.5055
# Epoch 20/20
# 785/785 [==============================] - 4s 5ms/step - loss: 0.0682 - accuracy: 0.9820 - val_loss: 3.7510 - val_accuracy: 0.5095

# %% [markdown]
# ##### Training Evaluation

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Baseline Training Loss', fontsize=20)
plt.legend(loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.xticks(np.arange(0,20,2))
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Baseline Training Accuracy', fontsize=20)
plt.legend(loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.xticks(np.arange(0,20,2))
plt.show()

# %% [markdown]
# ##### Testing

# %%
predictions = model.predict(image_test)
predicted_classes = tf.argmax(predictions, axis=1)

accuracy = accuracy_score(tf.argmax(label_test, axis=1).numpy(), predicted_classes)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 112/112 [==============================] - 0s 2ms/step
# Test Accuracy: 51.94%

# %% [markdown]
# # Data Augmentation

# %%
# func difference in labels
# param: list of label counts
# find max
# for each label count return a list that contains max-count

def diff_in_labels(counts):

    max_count =max(counts)

    diff_in_labels_list = []

    for count in counts:
        diff_in_labels_list.append(max_count-count)

    return diff_in_labels_list

# %%
# Creating the ImageDataGenerator
datagen = ImageDataGenerator(
    rotation_range=10,    # Small rotations, as large rotations might distort facial features
    width_shift_range=0.05,  # Slight horizontal shifts to simulate head movements
    height_shift_range=0.05,  # Slight vertical shifts
    shear_range=0.1,     # Small shearing; too much might change the expression
    zoom_range=0.05,      # Slight zooming in and out
    horizontal_flip=True,  # Flipping might be useful to generalize learning
    vertical_flip=False,   # Flipping vertically is less likely to represent real-world scenarios
    fill_mode='nearest',   # 'nearest' is typically preferred for facial data
)

# %%
def augment_images(images, labels):
    class_counts = np.sum(labels, axis=0)

    # Find the maximum class count
    max_class_count = np.max(class_counts)

    augmented_images = []
    augmented_labels = []

    # Iterate over each class
    for class_index in range(len(class_counts)):
        # Calculate how many images need to be generated for this class
        num_to_generate = int(max_class_count - class_counts[class_index])

        # Only generate if additional images are needed
        if num_to_generate > 0:
            # Filter images of the current class
            class_images = images[np.argmax(labels, axis=1) == class_index]
            class_labels = labels[np.argmax(labels, axis=1) == class_index]

            # Create a data generator for the current class
            data_generator = datagen.flow(class_images, class_labels, batch_size=1)

            # Generate required number of images
            for num in range(num_to_generate):
                img, num = next(data_generator)
                augmented_images.append(img[0])
                # Create a label for the augmented image
                label = np.zeros(len(class_counts))
                label[class_index] = 1
                augmented_labels.append(label)

    return np.array(augmented_images), np.array(augmented_labels)

# %%
augmented_images_train, augmented_labels_train = augment_images(image_train, label_train)

# %%
index = random.randint(0,augmented_images_train.shape[0]-1)
print(index)
plt.imshow(augmented_images_train[index], cmap='gray')
plt.axis('off') 
plt.show()
# Out:
# 14678

# %%
# Combining the augmented data with original data
images_train_augmented = np.concatenate([image_train, augmented_images_train])
labels_train_augmented = np.concatenate([label_train, augmented_labels_train])

# %%
index = random.randint(0,images_train_augmented.shape[0]-1)
print(index)
plt.imshow(images_train_augmented[index], cmap='gray')
plt.axis('off') 
plt.show()
# Out:
# 6206

# %% [markdown]
# # Improved Model

# %%
aug_model = Sequential()

# Convolutional layer 1
aug_model.add(Conv2D(16, kernel_size=(3, 3), activation='leaky_relu', input_shape=(48, 48, 1)))
aug_model.add(MaxPooling2D())
aug_model.add(Dropout(0.25))

# Convolutional layer 2
aug_model.add(Conv2D(32, kernel_size=(3, 3), activation='leaky_relu'))
aug_model.add(MaxPooling2D())
aug_model.add(Dropout(0.25))

# Convolutional layer 3
aug_model.add(Conv2D(64, kernel_size=(3, 3), activation='leaky_relu'))
aug_model.add(MaxPooling2D())
aug_model.add(Dropout(0.25))

# Convolutional layer 3
aug_model.add(Conv2D(128, kernel_size=(3, 3), activation='leaky_relu'))
aug_model.add(MaxPooling2D())
aug_model.add(Dropout(0.25))

# Flatten the data for dense layers
aug_model.add(Flatten())

# Dense layers
aug_model.add(Dense(128, activation='leaky_relu'))
aug_model.add(Dropout(0.25))
aug_model.add(Dense(7, activation='softmax'))  # 7 output classes for emotions

# Optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.001)

# Compile the model
aug_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
aug_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 46, 46, 16)        160
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 16)       0
#  2D)
#
#  dropout (Dropout)           (None, 23, 23, 16)        0
#
#  conv2d_3 (Conv2D)           (None, 21, 21, 32)        4640
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          18496
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 64)          0
#
#  conv2d_5 (Conv2D)           (None, 2, 2, 128)         73856
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 114,567
# Trainable params: 114,567
# Non-trainable params: 0
# _________________________________________________________________

# %%
aug_hist = aug_model.fit(images_train_augmented, labels_train_augmented, epochs=100, 
                    validation_data=(image_val, label_val), batch_size=64)
# Out:
# Epoch 1/100
# 2023-12-06 14:07:19.144512: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:1014] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 687/687 [==============================] - 8s 9ms/step - loss: 1.8161 - accuracy: 0.2614 - val_loss: 1.5326 - val_accuracy: 0.4133
# Epoch 2/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.5381 - accuracy: 0.4127 - val_loss: 1.4517 - val_accuracy: 0.4467
# Epoch 3/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.4224 - accuracy: 0.4624 - val_loss: 1.2972 - val_accuracy: 0.5088
# Epoch 4/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.3598 - accuracy: 0.4868 - val_loss: 1.3011 - val_accuracy: 0.5066
# Epoch 5/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.3101 - accuracy: 0.5052 - val_loss: 1.2481 - val_accuracy: 0.5310
# Epoch 6/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.2810 - accuracy: 0.5155 - val_loss: 1.2356 - val_accuracy: 0.5346
# Epoch 7/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.2546 - accuracy: 0.5250 - val_loss: 1.2049 - val_accuracy: 0.5476
# Epoch 8/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.2303 - accuracy: 0.5370 - val_loss: 1.2128 - val_accuracy: 0.5428
# Epoch 9/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.2130 - accuracy: 0.5444 - val_loss: 1.2128 - val_accuracy: 0.5475
# Epoch 10/100
# 687/687 [==============================] - 5s 8ms/step - loss: 1.1910 - accuracy: 0.5506 - val_loss: 1.1795 - val_accuracy: 0.5580
# Epoch 11/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.1774 - accuracy: 0.5557 - val_loss: 1.1596 - val_accuracy: 0.5620
# Epoch 12/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.1715 - accuracy: 0.5569 - val_loss: 1.1490 - val_accuracy: 0.5634
# Epoch 13/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.1577 - accuracy: 0.5636 - val_loss: 1.1989 - val_accuracy: 0.5432
# Epoch 14/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.1489 - accuracy: 0.5654 - val_loss: 1.1411 - val_accuracy: 0.5697
# Epoch 15/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.1393 - accuracy: 0.5697 - val_loss: 1.1421 - val_accuracy: 0.5702
# Epoch 16/100
# 687/687 [==============================] - 5s 8ms/step - loss: 1.1341 - accuracy: 0.5720 - val_loss: 1.1302 - val_accuracy: 0.5709
# Epoch 17/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.1251 - accuracy: 0.5784 - val_loss: 1.1295 - val_accuracy: 0.5722
# Epoch 18/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.1162 - accuracy: 0.5780 - val_loss: 1.1213 - val_accuracy: 0.5864
# Epoch 19/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.1084 - accuracy: 0.5820 - val_loss: 1.1222 - val_accuracy: 0.5827
# Epoch 20/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.1067 - accuracy: 0.5817 - val_loss: 1.1625 - val_accuracy: 0.5650
# Epoch 21/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.1001 - accuracy: 0.5838 - val_loss: 1.1175 - val_accuracy: 0.5827
# Epoch 22/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0948 - accuracy: 0.5860 - val_loss: 1.1167 - val_accuracy: 0.5787
# Epoch 23/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0948 - accuracy: 0.5869 - val_loss: 1.1114 - val_accuracy: 0.5878
# Epoch 24/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0879 - accuracy: 0.5875 - val_loss: 1.1273 - val_accuracy: 0.5783
# Epoch 25/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0811 - accuracy: 0.5915 - val_loss: 1.1201 - val_accuracy: 0.5838
# Epoch 26/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0759 - accuracy: 0.5950 - val_loss: 1.1399 - val_accuracy: 0.5752
# Epoch 27/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0768 - accuracy: 0.5914 - val_loss: 1.1223 - val_accuracy: 0.5774
# Epoch 28/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0687 - accuracy: 0.5955 - val_loss: 1.1258 - val_accuracy: 0.5799
# Epoch 29/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0642 - accuracy: 0.5981 - val_loss: 1.1068 - val_accuracy: 0.5841
# Epoch 30/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0657 - accuracy: 0.5985 - val_loss: 1.1061 - val_accuracy: 0.5857
# Epoch 31/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0627 - accuracy: 0.5978 - val_loss: 1.1135 - val_accuracy: 0.5859
# Epoch 32/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0560 - accuracy: 0.6004 - val_loss: 1.1126 - val_accuracy: 0.5781
# Epoch 33/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0560 - accuracy: 0.5995 - val_loss: 1.1346 - val_accuracy: 0.5784
# Epoch 34/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0511 - accuracy: 0.6026 - val_loss: 1.1120 - val_accuracy: 0.5826
# Epoch 35/100
# 687/687 [==============================] - 5s 8ms/step - loss: 1.0500 - accuracy: 0.6036 - val_loss: 1.0984 - val_accuracy: 0.5874
# Epoch 36/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0503 - accuracy: 0.6037 - val_loss: 1.1175 - val_accuracy: 0.5802
# Epoch 37/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0459 - accuracy: 0.6058 - val_loss: 1.0917 - val_accuracy: 0.5900
# Epoch 38/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0419 - accuracy: 0.6050 - val_loss: 1.1126 - val_accuracy: 0.5838
# Epoch 39/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0461 - accuracy: 0.6071 - val_loss: 1.0915 - val_accuracy: 0.5939
# Epoch 40/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0400 - accuracy: 0.6070 - val_loss: 1.1115 - val_accuracy: 0.5894
# Epoch 41/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0345 - accuracy: 0.6097 - val_loss: 1.1334 - val_accuracy: 0.5842
# Epoch 42/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0383 - accuracy: 0.6064 - val_loss: 1.1080 - val_accuracy: 0.5859
# Epoch 43/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0314 - accuracy: 0.6135 - val_loss: 1.0980 - val_accuracy: 0.5902
# Epoch 44/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0383 - accuracy: 0.6112 - val_loss: 1.0947 - val_accuracy: 0.5894
# Epoch 45/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0280 - accuracy: 0.6114 - val_loss: 1.1048 - val_accuracy: 0.5864
# Epoch 46/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0284 - accuracy: 0.6115 - val_loss: 1.0878 - val_accuracy: 0.5931
# Epoch 47/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0305 - accuracy: 0.6101 - val_loss: 1.0909 - val_accuracy: 0.5953
# Epoch 48/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0193 - accuracy: 0.6151 - val_loss: 1.0881 - val_accuracy: 0.5921
# Epoch 49/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0230 - accuracy: 0.6140 - val_loss: 1.0992 - val_accuracy: 0.5917
# Epoch 50/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0201 - accuracy: 0.6166 - val_loss: 1.0783 - val_accuracy: 0.5973
# Epoch 51/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0228 - accuracy: 0.6135 - val_loss: 1.0932 - val_accuracy: 0.5903
# Epoch 52/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0121 - accuracy: 0.6181 - val_loss: 1.0987 - val_accuracy: 0.5907
# Epoch 53/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0201 - accuracy: 0.6173 - val_loss: 1.1636 - val_accuracy: 0.5724
# Epoch 54/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0126 - accuracy: 0.6201 - val_loss: 1.0879 - val_accuracy: 0.5909
# Epoch 55/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0150 - accuracy: 0.6174 - val_loss: 1.1103 - val_accuracy: 0.5914
# Epoch 56/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0129 - accuracy: 0.6181 - val_loss: 1.0845 - val_accuracy: 0.5966
# Epoch 57/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0120 - accuracy: 0.6181 - val_loss: 1.0871 - val_accuracy: 0.5981
# Epoch 58/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0071 - accuracy: 0.6216 - val_loss: 1.0848 - val_accuracy: 0.5977
# Epoch 59/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0106 - accuracy: 0.6197 - val_loss: 1.0766 - val_accuracy: 0.5977
# Epoch 60/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0144 - accuracy: 0.6183 - val_loss: 1.0793 - val_accuracy: 0.6010
# Epoch 61/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0054 - accuracy: 0.6222 - val_loss: 1.0915 - val_accuracy: 0.5982
# Epoch 62/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0077 - accuracy: 0.6191 - val_loss: 1.0954 - val_accuracy: 0.5935
# Epoch 63/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0062 - accuracy: 0.6212 - val_loss: 1.0689 - val_accuracy: 0.6013
# Epoch 64/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0040 - accuracy: 0.6200 - val_loss: 1.0898 - val_accuracy: 0.5999
# Epoch 65/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0049 - accuracy: 0.6222 - val_loss: 1.0935 - val_accuracy: 0.5979
# Epoch 66/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9995 - accuracy: 0.6222 - val_loss: 1.0820 - val_accuracy: 0.6006
# Epoch 67/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0037 - accuracy: 0.6229 - val_loss: 1.0890 - val_accuracy: 0.5963
# Epoch 68/100
# 687/687 [==============================] - 6s 8ms/step - loss: 1.0004 - accuracy: 0.6228 - val_loss: 1.0823 - val_accuracy: 0.5978
# Epoch 69/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9959 - accuracy: 0.6256 - val_loss: 1.1202 - val_accuracy: 0.5877
# Epoch 70/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9975 - accuracy: 0.6239 - val_loss: 1.0914 - val_accuracy: 0.5966
# Epoch 71/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9988 - accuracy: 0.6273 - val_loss: 1.0725 - val_accuracy: 0.6029
# Epoch 72/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9992 - accuracy: 0.6258 - val_loss: 1.0832 - val_accuracy: 0.6004
# Epoch 73/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9939 - accuracy: 0.6262 - val_loss: 1.0928 - val_accuracy: 0.6011
# Epoch 74/100
# 687/687 [==============================] - 5s 8ms/step - loss: 0.9939 - accuracy: 0.6261 - val_loss: 1.0925 - val_accuracy: 0.5982
# Epoch 75/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9877 - accuracy: 0.6286 - val_loss: 1.0872 - val_accuracy: 0.5967
# Epoch 76/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9936 - accuracy: 0.6244 - val_loss: 1.0904 - val_accuracy: 0.6003
# Epoch 77/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9939 - accuracy: 0.6234 - val_loss: 1.0682 - val_accuracy: 0.6078
# Epoch 78/100
# 687/687 [==============================] - 5s 8ms/step - loss: 0.9874 - accuracy: 0.6289 - val_loss: 1.0861 - val_accuracy: 0.5941
# Epoch 79/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9895 - accuracy: 0.6273 - val_loss: 1.0951 - val_accuracy: 0.5950
# Epoch 80/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9928 - accuracy: 0.6251 - val_loss: 1.0971 - val_accuracy: 0.5941
# Epoch 81/100
# 687/687 [==============================] - 5s 8ms/step - loss: 0.9850 - accuracy: 0.6284 - val_loss: 1.0846 - val_accuracy: 0.6043
# Epoch 82/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9870 - accuracy: 0.6300 - val_loss: 1.0847 - val_accuracy: 0.5998
# Epoch 83/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9878 - accuracy: 0.6266 - val_loss: 1.0800 - val_accuracy: 0.5977
# Epoch 84/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9865 - accuracy: 0.6276 - val_loss: 1.0920 - val_accuracy: 0.6013
# Epoch 85/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9859 - accuracy: 0.6291 - val_loss: 1.0858 - val_accuracy: 0.6007
# Epoch 86/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9868 - accuracy: 0.6294 - val_loss: 1.0957 - val_accuracy: 0.6022
# Epoch 87/100
# 687/687 [==============================] - 5s 8ms/step - loss: 0.9862 - accuracy: 0.6263 - val_loss: 1.0810 - val_accuracy: 0.6061
# Epoch 88/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9877 - accuracy: 0.6279 - val_loss: 1.0873 - val_accuracy: 0.5984
# Epoch 89/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9910 - accuracy: 0.6279 - val_loss: 1.0955 - val_accuracy: 0.5959
# Epoch 90/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9812 - accuracy: 0.6319 - val_loss: 1.0906 - val_accuracy: 0.5952
# Epoch 91/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9842 - accuracy: 0.6287 - val_loss: 1.0843 - val_accuracy: 0.6035
# Epoch 92/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9827 - accuracy: 0.6305 - val_loss: 1.0859 - val_accuracy: 0.6007
# Epoch 93/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9857 - accuracy: 0.6307 - val_loss: 1.0795 - val_accuracy: 0.6016
# Epoch 94/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9861 - accuracy: 0.6298 - val_loss: 1.0742 - val_accuracy: 0.6028
# Epoch 95/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9784 - accuracy: 0.6318 - val_loss: 1.0851 - val_accuracy: 0.6018
# Epoch 96/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9862 - accuracy: 0.6316 - val_loss: 1.0902 - val_accuracy: 0.5996
# Epoch 97/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9815 - accuracy: 0.6309 - val_loss: 1.0811 - val_accuracy: 0.6014
# Epoch 98/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9732 - accuracy: 0.6319 - val_loss: 1.0912 - val_accuracy: 0.6017
# Epoch 99/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9789 - accuracy: 0.6312 - val_loss: 1.0713 - val_accuracy: 0.6056
# Epoch 100/100
# 687/687 [==============================] - 6s 8ms/step - loss: 0.9787 - accuracy: 0.6330 - val_loss: 1.0761 - val_accuracy: 0.6027

# %%
fig = plt.figure()
plt.plot(aug_hist.history['loss'], color='teal', label='loss')
plt.plot(aug_hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Improved Model Training Loss', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
fig = plt.figure()
plt.plot(aug_hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(aug_hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Improved Model Training Accuracy', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
predictions = aug_model.predict(image_test)
predicted_classes = tf.argmax(predictions, axis=1)

accuracy = accuracy_score(tf.argmax(label_test, axis=1).numpy(), predicted_classes)

test_loss, test_acc = aug_model.evaluate(image_test, label_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 112/112 [==============================] - 0s 3ms/step
# 112/112 [==============================] - 0s 3ms/step - loss: 1.0609 - accuracy: 0.6027
# Test Accuracy: 60.27%

# %%
y_true = np.argmax(label_test, axis=1)
y_pred = np.argmax(predictions, axis=1)

# %%
cm = confusion_matrix(y_true, predicted_classes)
cmp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['anger','disgust','fear','happy','sad','surprise','neut'])
cmp.plot()
plt.show()

# %% [markdown]
# # Remove Data

# %%
# Drop 'Category 1'
df = face_data_df[face_data_df['emotion'] != 1]
df = df[df['emotion'] != 6]

# %%
# Find the count of the smallest category, excluding 'Category 3'
min_category_count = df[df['emotion'] != 3]['emotion'].value_counts().min()

# Downsample 'Category 3'
df_category3_downsampled = df[df['emotion'] == 3].sample(min_category_count, random_state=0)
df_other_categories = df[df['emotion'] != 3]

# Combine the downsampled category with the rest
face_data_df_downsampled = pd.concat([df_category3_downsampled, df_other_categories])

# Shuffle the dataset
face_data_df_downsampled = face_data_df_downsampled.sample(frac=1, random_state=0).reset_index(drop=True)

# %%
# split into images and labels
images = face_data_df_downsampled[' pixels'].to_numpy()
labels = face_data_df_downsampled['emotion'].to_numpy()

# normalize images
images = np.stack(images, axis=0)

# renumber labels
labels = np.where(labels > 0, labels - 1, labels)

# one hot encode labels
labels = tf.keras.utils.to_categorical(labels, num_classes=5)

# split data into train/validation/testing 70%/20%/10%

# 70% training, 30% temp
image_train, image_temp, label_train, label_temp = train_test_split(images, labels, test_size=0.3)  

# 67% training, 33% temp
image_val, image_test, label_val, label_test = train_test_split(image_temp, label_temp, test_size=0.33)

# %% [markdown]
# # Emotion Recognition Model

# %%
'''
These callback methods were taken from 
https://www.kaggle.com/code/gauravsharma99/facial-emotion-recognition
'''


early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.00005,
    patience=11,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
    early_stopping,
    lr_scheduler,
]

# %%
eRec_model = Sequential()

# Convolutional layer 1
eRec_model.add(Conv2D(16, kernel_size=(3, 3), input_shape=(48, 48, 1), kernel_initializer= 'glorot_normal'))
eRec_model.add(BatchNormalization())
eRec_model.add(Activation(activation='leaky_relu'))
eRec_model.add(MaxPooling2D())
eRec_model.add(Dropout(0.25))

# Convolutional layer 2
eRec_model.add(Conv2D(32, kernel_size=(3, 3), kernel_initializer= 'glorot_normal'))
eRec_model.add(BatchNormalization())
eRec_model.add(Activation(activation='leaky_relu'))
eRec_model.add(MaxPooling2D())
eRec_model.add(Dropout(0.25))

# Convolutional layer 3
eRec_model.add(Conv2D(64, kernel_size=(3, 3), kernel_initializer= 'glorot_normal'))
eRec_model.add(BatchNormalization())
eRec_model.add(Activation(activation='leaky_relu'))
eRec_model.add(MaxPooling2D())
eRec_model.add(Dropout(0.25))

# Convolutional layer 4
eRec_model.add(Conv2D(128, kernel_size=(3, 3), kernel_initializer= 'glorot_normal'))
eRec_model.add(BatchNormalization())
eRec_model.add(Activation(activation='leaky_relu'))
eRec_model.add(MaxPooling2D())
eRec_model.add(Dropout(0.25))

# Flatten the data for dense layers
eRec_model.add(Flatten())

# Dense layers
eRec_model.add(Dense(128, activation='leaky_relu') )
eRec_model.add(Dropout(0.25))
eRec_model.add(Dense(5, activation='softmax'))  # 5 output classes for emotions

# Optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.001)

# Compile the model
eRec_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
eRec_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 46, 46, 16)        160
#
#  batch_normalization (BatchN  (None, 46, 46, 16)       64
#  ormalization)
#
#  activation (Activation)     (None, 46, 46, 16)        0
#
#  max_pooling2d_6 (MaxPooling  (None, 23, 23, 16)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 23, 23, 16)        0
#
#  conv2d_7 (Conv2D)           (None, 21, 21, 32)        4640
#
#  batch_normalization_1 (Batc  (None, 21, 21, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 21, 21, 32)        0
#
#  max_pooling2d_7 (MaxPooling  (None, 10, 10, 32)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 10, 10, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 64)          18496
#
#  batch_normalization_2 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 8, 8, 64)          0
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  dropout_7 (Dropout)         (None, 4, 4, 64)          0
#
#  conv2d_9 (Conv2D)           (None, 2, 2, 128)         73856
#
#  batch_normalization_3 (Batc  (None, 2, 2, 128)        512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 2, 2, 128)         0
#
#  max_pooling2d_9 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_8 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 115,269
# Trainable params: 114,789
# Non-trainable params: 480
# _________________________________________________________________

# %%
eRec_hist = eRec_model.fit(image_train, label_train, epochs=100, 
                    validation_data=(image_val, label_val), batch_size=128, callbacks=callbacks )
# Out:
# Epoch 1/100
# 2023-12-06 14:18:03.897091: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:1014] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_2/dropout_5/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 133/133 [==============================] - 5s 17ms/step - loss: 1.6564 - accuracy: 0.2731 - val_loss: 1.5460 - val_accuracy: 0.2925 - lr: 0.0010
# Epoch 2/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.4900 - accuracy: 0.3407 - val_loss: 1.3972 - val_accuracy: 0.4074 - lr: 0.0010
# Epoch 3/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.4178 - accuracy: 0.3781 - val_loss: 1.3300 - val_accuracy: 0.4336 - lr: 0.0010
# Epoch 4/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.3676 - accuracy: 0.4063 - val_loss: 1.3148 - val_accuracy: 0.4282 - lr: 0.0010
# Epoch 5/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.3354 - accuracy: 0.4278 - val_loss: 1.2585 - val_accuracy: 0.4624 - lr: 0.0010
# Epoch 6/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.3057 - accuracy: 0.4429 - val_loss: 1.2261 - val_accuracy: 0.4931 - lr: 0.0010
# Epoch 7/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.2768 - accuracy: 0.4614 - val_loss: 1.1834 - val_accuracy: 0.4925 - lr: 0.0010
# Epoch 8/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.2517 - accuracy: 0.4700 - val_loss: 1.3528 - val_accuracy: 0.4278 - lr: 0.0010
# Epoch 9/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.2290 - accuracy: 0.4827 - val_loss: 1.1698 - val_accuracy: 0.5215 - lr: 0.0010
# Epoch 10/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.2004 - accuracy: 0.4988 - val_loss: 1.1498 - val_accuracy: 0.5205 - lr: 0.0010
# Epoch 11/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.1793 - accuracy: 0.5077 - val_loss: 1.1063 - val_accuracy: 0.5337 - lr: 0.0010
# Epoch 12/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.1656 - accuracy: 0.5123 - val_loss: 1.1045 - val_accuracy: 0.5434 - lr: 0.0010
# Epoch 13/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.1447 - accuracy: 0.5257 - val_loss: 1.0864 - val_accuracy: 0.5493 - lr: 0.0010
# Epoch 14/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.1325 - accuracy: 0.5312 - val_loss: 1.0606 - val_accuracy: 0.5666 - lr: 0.0010
# Epoch 15/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.1102 - accuracy: 0.5337 - val_loss: 1.0758 - val_accuracy: 0.5582 - lr: 0.0010
# Epoch 16/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.1033 - accuracy: 0.5443 - val_loss: 1.0758 - val_accuracy: 0.5512 - lr: 0.0010
# Epoch 17/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0934 - accuracy: 0.5500 - val_loss: 1.0510 - val_accuracy: 0.5693 - lr: 0.0010
# Epoch 18/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0799 - accuracy: 0.5550 - val_loss: 1.0255 - val_accuracy: 0.5798 - lr: 0.0010
# Epoch 19/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0645 - accuracy: 0.5601 - val_loss: 1.0636 - val_accuracy: 0.5520 - lr: 0.0010
# Epoch 20/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0536 - accuracy: 0.5676 - val_loss: 1.0175 - val_accuracy: 0.5860 - lr: 0.0010
# Epoch 21/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0473 - accuracy: 0.5638 - val_loss: 1.0079 - val_accuracy: 0.5922 - lr: 0.0010
# Epoch 22/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0343 - accuracy: 0.5728 - val_loss: 1.0112 - val_accuracy: 0.5868 - lr: 0.0010
# Epoch 23/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0228 - accuracy: 0.5814 - val_loss: 1.1042 - val_accuracy: 0.5407 - lr: 0.0010
# Epoch 24/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0146 - accuracy: 0.5862 - val_loss: 1.1035 - val_accuracy: 0.5495 - lr: 0.0010
# Epoch 25/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0175 - accuracy: 0.5842 - val_loss: 1.0364 - val_accuracy: 0.5730 - lr: 0.0010
# Epoch 26/100
# 133/133 [==============================] - 2s 13ms/step - loss: 1.0001 - accuracy: 0.5861 - val_loss: 0.9848 - val_accuracy: 0.6031 - lr: 0.0010
# Epoch 27/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9861 - accuracy: 0.5968 - val_loss: 1.0734 - val_accuracy: 0.5701 - lr: 0.0010
# Epoch 28/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9901 - accuracy: 0.5942 - val_loss: 0.9842 - val_accuracy: 0.5998 - lr: 0.0010
# Epoch 29/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9807 - accuracy: 0.5995 - val_loss: 0.9995 - val_accuracy: 0.5829 - lr: 0.0010
# Epoch 30/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9739 - accuracy: 0.6026 - val_loss: 0.9919 - val_accuracy: 0.5951 - lr: 0.0010
# Epoch 31/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9623 - accuracy: 0.6082 - val_loss: 0.9772 - val_accuracy: 0.6054 - lr: 0.0010
# Epoch 32/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9579 - accuracy: 0.6092 - val_loss: 0.9585 - val_accuracy: 0.6202 - lr: 0.0010
# Epoch 33/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9504 - accuracy: 0.6112 - val_loss: 0.9734 - val_accuracy: 0.6039 - lr: 0.0010
# Epoch 34/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9409 - accuracy: 0.6169 - val_loss: 1.0004 - val_accuracy: 0.5940 - lr: 0.0010
# Epoch 35/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9355 - accuracy: 0.6169 - val_loss: 0.9688 - val_accuracy: 0.6082 - lr: 0.0010
# Epoch 36/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9236 - accuracy: 0.6237 - val_loss: 0.9544 - val_accuracy: 0.6196 - lr: 0.0010
# Epoch 37/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9204 - accuracy: 0.6308 - val_loss: 0.9576 - val_accuracy: 0.6115 - lr: 0.0010
# Epoch 38/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9095 - accuracy: 0.6315 - val_loss: 0.9479 - val_accuracy: 0.6173 - lr: 0.0010
# Epoch 39/100
# 130/133 [============================>.] - ETA: 0s - loss: 0.9118 - accuracy: 0.6293
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 133/133 [==============================] - 2s 13ms/step - loss: 0.9104 - accuracy: 0.6295 - val_loss: 0.9581 - val_accuracy: 0.6157 - lr: 0.0010
# Epoch 40/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8828 - accuracy: 0.6477 - val_loss: 0.9791 - val_accuracy: 0.6087 - lr: 5.0000e-04
# Epoch 41/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8776 - accuracy: 0.6441 - val_loss: 0.9648 - val_accuracy: 0.6157 - lr: 5.0000e-04
# Epoch 42/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8747 - accuracy: 0.6470 - val_loss: 0.9546 - val_accuracy: 0.6179 - lr: 5.0000e-04
# Epoch 43/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8623 - accuracy: 0.6521 - val_loss: 0.9365 - val_accuracy: 0.6272 - lr: 5.0000e-04
# Epoch 44/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8624 - accuracy: 0.6496 - val_loss: 0.9572 - val_accuracy: 0.6233 - lr: 5.0000e-04
# Epoch 45/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8604 - accuracy: 0.6497 - val_loss: 0.9446 - val_accuracy: 0.6179 - lr: 5.0000e-04
# Epoch 46/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8461 - accuracy: 0.6592 - val_loss: 0.9495 - val_accuracy: 0.6229 - lr: 5.0000e-04
# Epoch 47/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8492 - accuracy: 0.6615 - val_loss: 0.9271 - val_accuracy: 0.6348 - lr: 5.0000e-04
# Epoch 48/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8406 - accuracy: 0.6597 - val_loss: 0.9370 - val_accuracy: 0.6272 - lr: 5.0000e-04
# Epoch 49/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8398 - accuracy: 0.6603 - val_loss: 0.9608 - val_accuracy: 0.6196 - lr: 5.0000e-04
# Epoch 50/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8408 - accuracy: 0.6609 - val_loss: 0.9304 - val_accuracy: 0.6319 - lr: 5.0000e-04
# Epoch 51/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8378 - accuracy: 0.6636 - val_loss: 0.9321 - val_accuracy: 0.6305 - lr: 5.0000e-04
# Epoch 52/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8296 - accuracy: 0.6654 - val_loss: 0.9401 - val_accuracy: 0.6264 - lr: 5.0000e-04
# Epoch 53/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8302 - accuracy: 0.6646 - val_loss: 0.9351 - val_accuracy: 0.6327 - lr: 5.0000e-04
# Epoch 54/100
# 131/133 [============================>.] - ETA: 0s - loss: 0.8240 - accuracy: 0.6675
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8235 - accuracy: 0.6673 - val_loss: 0.9287 - val_accuracy: 0.6307 - lr: 5.0000e-04
# Epoch 55/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8121 - accuracy: 0.6738 - val_loss: 0.9375 - val_accuracy: 0.6334 - lr: 2.5000e-04
# Epoch 56/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8154 - accuracy: 0.6699 - val_loss: 0.9393 - val_accuracy: 0.6272 - lr: 2.5000e-04
# Epoch 57/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8091 - accuracy: 0.6807 - val_loss: 0.9256 - val_accuracy: 0.6356 - lr: 2.5000e-04
# Epoch 58/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8134 - accuracy: 0.6743 - val_loss: 0.9277 - val_accuracy: 0.6352 - lr: 2.5000e-04
# Epoch 59/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.8059 - accuracy: 0.6775 - val_loss: 0.9246 - val_accuracy: 0.6381 - lr: 2.5000e-04
# Epoch 60/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7998 - accuracy: 0.6782 - val_loss: 0.9277 - val_accuracy: 0.6319 - lr: 2.5000e-04
# Epoch 61/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7984 - accuracy: 0.6757 - val_loss: 0.9311 - val_accuracy: 0.6334 - lr: 2.5000e-04
# Epoch 62/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7968 - accuracy: 0.6842 - val_loss: 0.9310 - val_accuracy: 0.6360 - lr: 2.5000e-04
# Epoch 63/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7950 - accuracy: 0.6772 - val_loss: 0.9340 - val_accuracy: 0.6332 - lr: 2.5000e-04
# Epoch 64/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7968 - accuracy: 0.6835 - val_loss: 0.9411 - val_accuracy: 0.6276 - lr: 2.5000e-04
# Epoch 65/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7944 - accuracy: 0.6817 - val_loss: 0.9305 - val_accuracy: 0.6321 - lr: 2.5000e-04
# Epoch 66/100
# 131/133 [============================>.] - ETA: 0s - loss: 0.7867 - accuracy: 0.6839
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7882 - accuracy: 0.6831 - val_loss: 0.9377 - val_accuracy: 0.6307 - lr: 2.5000e-04
# Epoch 67/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7818 - accuracy: 0.6889 - val_loss: 0.9234 - val_accuracy: 0.6400 - lr: 1.2500e-04
# Epoch 68/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7853 - accuracy: 0.6888 - val_loss: 0.9261 - val_accuracy: 0.6414 - lr: 1.2500e-04
# Epoch 69/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7863 - accuracy: 0.6899 - val_loss: 0.9240 - val_accuracy: 0.6402 - lr: 1.2500e-04
# Epoch 70/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7817 - accuracy: 0.6845 - val_loss: 0.9235 - val_accuracy: 0.6428 - lr: 1.2500e-04
# Epoch 71/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7754 - accuracy: 0.6912 - val_loss: 0.9291 - val_accuracy: 0.6408 - lr: 1.2500e-04
# Epoch 72/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7866 - accuracy: 0.6819 - val_loss: 0.9281 - val_accuracy: 0.6375 - lr: 1.2500e-04
# Epoch 73/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7740 - accuracy: 0.6894 - val_loss: 0.9240 - val_accuracy: 0.6418 - lr: 1.2500e-04
# Epoch 74/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7745 - accuracy: 0.6926 - val_loss: 0.9276 - val_accuracy: 0.6406 - lr: 1.2500e-04
# Epoch 75/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7811 - accuracy: 0.6884 - val_loss: 0.9223 - val_accuracy: 0.6445 - lr: 1.2500e-04
# Epoch 76/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7703 - accuracy: 0.6950 - val_loss: 0.9268 - val_accuracy: 0.6412 - lr: 1.2500e-04
# Epoch 77/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7683 - accuracy: 0.6931 - val_loss: 0.9297 - val_accuracy: 0.6404 - lr: 1.2500e-04
# Epoch 78/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7817 - accuracy: 0.6849 - val_loss: 0.9222 - val_accuracy: 0.6443 - lr: 1.2500e-04
# Epoch 79/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7697 - accuracy: 0.6935 - val_loss: 0.9270 - val_accuracy: 0.6404 - lr: 1.2500e-04
# Epoch 80/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7748 - accuracy: 0.6929 - val_loss: 0.9245 - val_accuracy: 0.6465 - lr: 1.2500e-04
# Epoch 81/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7662 - accuracy: 0.6912 - val_loss: 0.9233 - val_accuracy: 0.6437 - lr: 1.2500e-04
# Epoch 82/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7643 - accuracy: 0.6961 - val_loss: 0.9271 - val_accuracy: 0.6418 - lr: 1.2500e-04
# Epoch 83/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7713 - accuracy: 0.6933 - val_loss: 0.9282 - val_accuracy: 0.6402 - lr: 1.2500e-04
# Epoch 84/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7715 - accuracy: 0.6875 - val_loss: 0.9251 - val_accuracy: 0.6447 - lr: 1.2500e-04
# Epoch 85/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7592 - accuracy: 0.6955 - val_loss: 0.9285 - val_accuracy: 0.6447 - lr: 1.2500e-04
# Epoch 86/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7625 - accuracy: 0.6945 - val_loss: 0.9329 - val_accuracy: 0.6400 - lr: 1.2500e-04
# Epoch 87/100
# 131/133 [============================>.] - ETA: 0s - loss: 0.7750 - accuracy: 0.6893
# Epoch 87: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7747 - accuracy: 0.6896 - val_loss: 0.9334 - val_accuracy: 0.6402 - lr: 1.2500e-04
# Epoch 88/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7609 - accuracy: 0.6971 - val_loss: 0.9247 - val_accuracy: 0.6437 - lr: 6.2500e-05
# Epoch 89/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7600 - accuracy: 0.6968 - val_loss: 0.9259 - val_accuracy: 0.6447 - lr: 6.2500e-05
# Epoch 90/100
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7553 - accuracy: 0.6991 - val_loss: 0.9281 - val_accuracy: 0.6461 - lr: 6.2500e-05
# Epoch 91/100
# 130/133 [============================>.] - ETA: 0s - loss: 0.7612 - accuracy: 0.6987Restoring model weights from the end of the best epoch: 80.
# 133/133 [==============================] - 2s 13ms/step - loss: 0.7621 - accuracy: 0.6982 - val_loss: 0.9244 - val_accuracy: 0.6443 - lr: 6.2500e-05
# Epoch 91: early stopping

# %%
fig = plt.figure()
plt.plot(eRec_hist.history['loss'], color='teal', label='loss')
plt.plot(eRec_hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Improved Model v2 Training Loss', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
fig = plt.figure()
plt.plot(eRec_hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(eRec_hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Improved Model v2 Training Accuracy', fontsize=20)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')
plt.show()

# %%
predictions = eRec_model.predict(image_test)
predicted_classes = tf.argmax(predictions, axis=1)

test_loss, test_acc = eRec_model.evaluate(image_test, label_test)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# 75/75 [==============================] - 0s 3ms/step
# 75/75 [==============================] - 0s 3ms/step - loss: 0.9030 - accuracy: 0.6451
# Test Accuracy: 64.51%

# %%
y_true = np.argmax(label_test, axis=1)
y_pred = np.argmax(predictions, axis=1)

# %%
cm = confusion_matrix(y_true, predicted_classes)
cmp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['angry',"afraid","happy","sad","surprised"])
cmp.plot()
plt.show()

# %% [markdown]
# # Save Model

# %%
from tensorflow.keras.models import load_model

model.save("model.h5")
aug_model.save("aug_model.h5")
eRec_model.save("eRec_model.h5")
